# %%
# !pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 2.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/11.0 MB 3.2 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/11.0 MB 3.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.1/11.0 MB 3.8 MB/s eta 0:00:03
#    -------------- ------------------------- 3.9/11.0 MB 3.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.7/11.0 MB 3.9 MB/s eta 0:00:02
#    --------------------- ------------------ 5.8/11.0 MB 4.0 MB/s eta 0:00:02
#    ------------------------ --------------- 6.8/11.0 MB 4.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.9/11.0 MB 4.2 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 4.4 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# Lire seulement les 100 premières lignes du fi
df = pd.read_csv('FoodProduct.csv', nrows=100, sep='\t')

# Sauvegarder dans un nouveau fichier CSV
df.to_csv('FoodProduct_sample.csv', index=False)
